# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
# Load the dataset
df = pd.read_csv('database.csv', header=0)

# %%
X = df[['b','h','t','l','fy','Ea','Fc']]
y = df['Ntest']

# %%
# Scale features and target variable to [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(20, activation='sigmoid'),
    # tf.keras.layers.Dense(20, activation='tanh'),
    tf.keras.layers.Dense(20, activation='sigmoid'),
    tf.keras.layers.Dense(1,activation='sigmoid')  # Output layer for regression
])

# %%
# Compile the model
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=custom_optimizer, loss='mean_squared_error', metrics=["mean_absolute_percentage_error"])

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_mean_absolute_percentage_error', patience=500, restore_best_weights=True)
# Model checkpoint callback
checkpoint = ModelCheckpoint("best_model.h5", save_best_only=True)
# TensorBoard callback for profiling
tensorboard = TensorBoard(log_dir="logs/")

# %%
# Train the model
model.fit(X_train, y_train, epochs=500000, batch_size=5000, verbose=2, validation_split=0.1, callbacks=[early_stopping, checkpoint, tensorboard])
# Out:
# Epoch 1/500000
# 1/1 - 1s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 663ms/epoch - 663ms/step
# Epoch 2/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 3/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 33ms/epoch - 33ms/step
# Epoch 4/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 5/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 6/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 7/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 8/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 9/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 10/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 11/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 12/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 13/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 14/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 15/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 16/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 17/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 18/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 19/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 20/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 21/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 22/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 23/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 24/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 25/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 26/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 27/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 28/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 29/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 30/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 31/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 32/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 33/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 34/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 35/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 36/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 37/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 38/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 39/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 40/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 41/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 42/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 43/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 44/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 45/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 46/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 47/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 48/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 49/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 50/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 51/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 52/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 53/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 54/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 55/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 56/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 57/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 58/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 59/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 60/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 61/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 62/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 63/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 64/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 65/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 34ms/epoch - 34ms/step
# Epoch 66/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 67/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 68/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 69/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 70/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 71/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 37ms/epoch - 37ms/step
# Epoch 72/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 73/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 74/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 75/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 76/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 77/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 78/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 79/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 80/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 81/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 82/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 83/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 84/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 85/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 86/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 87/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 88/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 89/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 90/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 91/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 92/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 93/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 94/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 95/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 96/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 97/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 98/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 99/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 100/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 101/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 102/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 103/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 104/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 105/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 106/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 107/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 108/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 109/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 110/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 111/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 112/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 113/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 114/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 115/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 116/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 117/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 118/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 119/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 120/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 121/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 122/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 123/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 124/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 125/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 126/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 127/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 128/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 129/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 130/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 131/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 132/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 133/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 134/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 135/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 136/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 137/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 138/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 139/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 140/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 141/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 142/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 143/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 144/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 145/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 146/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 147/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 148/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 149/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 150/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 151/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 152/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 153/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 154/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 155/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 156/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 157/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 158/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 159/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 160/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 161/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 162/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 163/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 164/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 165/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 166/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 167/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 168/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 169/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 170/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 171/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 172/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 173/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 174/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 175/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 176/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 177/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 178/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 179/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 180/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 181/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 182/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 183/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 184/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 185/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 186/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 187/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 188/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 189/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 190/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 191/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 192/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 193/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 194/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 195/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 196/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 197/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 198/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 199/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 200/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 19ms/epoch - 19ms/step
# Epoch 201/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 202/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 203/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 204/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 205/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 206/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 207/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 208/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 209/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 210/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 211/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 212/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 213/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 214/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 215/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 32ms/epoch - 32ms/step
# Epoch 216/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 217/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 218/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 219/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 220/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 221/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 222/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 223/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 224/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 225/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 226/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 227/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 228/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 229/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 230/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 231/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 232/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 31ms/epoch - 31ms/step
# Epoch 233/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 234/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 235/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 236/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 237/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 238/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 239/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 240/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 241/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 242/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 243/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 244/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 245/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 246/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 38ms/epoch - 38ms/step
# Epoch 247/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 248/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 249/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 250/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 251/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 252/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 253/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 254/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 255/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 256/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 257/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 258/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 259/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 260/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 261/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 262/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 263/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 264/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 265/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 266/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 267/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 268/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 269/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 270/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 271/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 272/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 273/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 32ms/epoch - 32ms/step
# Epoch 274/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 275/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 276/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 277/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 278/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 279/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 280/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 281/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 282/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 283/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 284/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 285/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 286/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 287/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 288/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 289/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 290/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 291/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 292/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 293/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 294/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 295/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 296/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 297/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 298/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 299/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 300/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 301/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 302/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 303/500000
# ...
# Epoch 401/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 402/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 403/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 404/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 405/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 406/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 407/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 408/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 409/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 410/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 411/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 412/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 413/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 414/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 415/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 416/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 417/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 418/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 419/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 420/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 421/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 422/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 37ms/epoch - 37ms/step
# Epoch 423/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 31ms/epoch - 31ms/step
# Epoch 424/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 425/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 426/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 427/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 428/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 429/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 430/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 431/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 432/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 433/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 434/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 435/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 436/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 437/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 438/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 27ms/epoch - 27ms/step
# Epoch 439/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 39ms/epoch - 39ms/step
# Epoch 440/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 441/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 442/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 443/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 444/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 445/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 446/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 447/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 448/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 449/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 450/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 451/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 452/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 453/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 454/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 455/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 38ms/epoch - 38ms/step
# Epoch 456/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 36ms/epoch - 36ms/step
# Epoch 457/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 458/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 459/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 460/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 461/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 462/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 463/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 464/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 465/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 21ms/epoch - 21ms/step
# Epoch 466/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 467/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 468/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 32ms/epoch - 32ms/step
# Epoch 469/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 470/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 471/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 472/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 30ms/epoch - 30ms/step
# Epoch 473/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 474/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 29ms/epoch - 29ms/step
# Epoch 475/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 28ms/epoch - 28ms/step
# Epoch 476/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 477/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 32ms/epoch - 32ms/step
# Epoch 478/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 479/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 480/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 481/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 482/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 483/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 484/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 485/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 486/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 26ms/epoch - 26ms/step
# Epoch 487/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 488/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 33ms/epoch - 33ms/step
# Epoch 489/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 490/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 491/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 492/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 20ms/epoch - 20ms/step
# Epoch 493/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 494/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 495/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step
# Epoch 496/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 24ms/epoch - 24ms/step
# Epoch 497/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 498/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 23ms/epoch - 23ms/step
# Epoch 499/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 22ms/epoch - 22ms/step
# Epoch 500/500000
# 1/1 - 0s - loss: nan - mean_absolute_percentage_error: nan - val_loss: nan - val_mean_absolute_percentage_error: nan - 25ms/epoch - 25ms/step

# %%
# Evaluate the model
loss, mae = model.evaluate(X_train, y_train)
print("Train Loss:", loss, "Train MAE:", mae)

loss, mae = model.evaluate(X_test, y_test)
print("Test Loss:", loss, "Test MAE:", mae)
# Out:
# 30/30 [==============================] - 0s 1ms/step - loss: nan - mean_absolute_percentage_error: nan
# Train Loss: nan Train MAE: nan
# 2/2 [==============================] - 0s 3ms/step - loss: nan - mean_absolute_percentage_error: nan
# Test Loss: nan Test MAE: nan

# %%
# Save the model
model.save('my_model')
# Out:
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52068640>, 140025903081440), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52068640>, 140025903081440), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52069a50>, 140032242385664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52069a50>, 140032242385664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206a6e0>, 140025903254784), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206a6e0>, 140025903254784), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206b7c0>, 140025903104688), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206b7c0>, 140025903104688), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a45b0>, 140025903257024), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a45b0>, 140025903257024), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5540>, 140025903256624), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5540>, 140025903256624), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5d20>, 140025903260464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5d20>, 140025903260464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a6e60>, 140025885129536), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a6e60>, 140025885129536), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52068640>, 140025903081440), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(7, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52068640>, 140025903081440), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52069a50>, 140032242385664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a52069a50>, 140032242385664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206a6e0>, 140025903254784), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206a6e0>, 140025903254784), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206b7c0>, 140025903104688), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a5206b7c0>, 140025903104688), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a45b0>, 140025903257024), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 20), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a45b0>, 140025903257024), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5540>, 140025903256624), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5540>, 140025903256624), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5d20>, 140025903260464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(20, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a5d20>, 140025903260464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a6e60>, 140025885129536), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f5a516a6e60>, 140025885129536), {}).
# INFO:tensorflow:Assets written to: my_model/assets
# INFO:tensorflow:Assets written to: my_model/assets

# %%
# Make predictions
y_pre = model.predict(X_test)
y_pre = [i[0] for i in y_pre]

# Calculate and save errors
# error = (y_test - y_pre) / y_test * 100
# error = error.sort_values()
# error.to_csv('error.csv', index=False)
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
y_test
# Out:
# array([[0.21966226],
#        [0.06449403],
#        [0.07291622],
#        [0.04515153],
#        [0.06102522],
#        [0.25998887],
#        [0.14757398],
#        [0.02259718],
#        [0.53035559],
#        [0.07741282],
#        [0.06198164],
#        [0.05314548],
#        [0.09882518],
#        [0.15549655],
#        [0.62856694],
#        [0.0872625 ],
#        [0.00129902],
#        [0.12380626],
#        [0.02797882],
#        [0.06827688],
#        [0.27226528],
#        [0.2285127 ],
#        [0.11110159],
#        [0.12095128],
#        [0.15806604],
#        [0.13451244],
#        [0.33314776],
#        [0.04283899],
#        [0.04757826],
#        [0.06171042],
#        [0.0191712 ],
#        [0.0606398 ],
#        [0.05650008],
#        [0.07477196],
#        [0.05542946],
#        [0.12059441],
#        [0.08619188],
#        [0.18518836],
#        [0.24657045],
#        [0.02345367],
#        [0.02898877],
#        [0.11666881],
#        [0.14521862],
#        [0.15249882],
#        [0.03801408],
#        [0.1665596 ],
#        [0.17733716],
#        [0.07405821],
#        [0.23507915],
#        [0.22301686],
#        [0.09240147]])

# %%
y_pre
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]
